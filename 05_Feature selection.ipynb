# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import Lasso, Ridge, LinearRegression
from sklearn.svm import LinearSVR
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder

# %%
feature_sele_df = pd.read_pickle('step_4_df.pkl')

# %% [markdown]
# # Feature Selection Script
#
# ## Overview
# This script performs feature selection on a dataset to determine which features are most important for predicting a target variable, `Price`. It utilizes multiple regression models to evaluate the significance of each feature and selects those that meet certain criteria.
#
# ## Libraries Used
# - **Pandas**: Data manipulation and analysis.
# - **NumPy**: Numerical operations.
# - **Seaborn**: Data visualization.
# - **Scikit-Learn**: Machine learning models and feature selection.
#
# ## Script Breakdown
#
# ### 1. Data Loading
# - Load the dataset from `step_4_df.pkl`.
#
# ### 2. Feature Selection
# - **Data Preparation**:
#   - Define feature matrix `X` and target variable `y`.
#   - Encode string columns using `OrdinalEncoder`.
# - **Model Fitting**:
#   - Fit various regression models (Lasso, SVM, Gradient Boosting, Random Forest, Linear Regression, Ridge) on the data.
#   - Determine if a feature is selected (1) or not (0) by each model.
# - **Results Compilation**:
#   - Create a DataFrame `selection_df` to store feature selection results from all models.
#   - Calculate the sum of selections for each feature across all models.
#
# ### 3. Feature Count by Threshold
# - Define thresholds to test and count the number of features selected for each threshold.
#
# ### 4. Final Feature Selection
# - Select features with a sum of selections greater than or equal to 4.
# - Save the final selected features into a new DataFrame `df_model`.

# %%
# Example data preparation
# Assuming X and y are your feature matrix and target variable
# X, y = your_data_preparation_function()
X = feature_sele_df.drop('Price', axis=1)  # Features

y = feature_sele_df['Price']  # Target variable
X.shape
#X.info()
# Out:
# (12583, 59)

# %%
string_columns = X.select_dtypes(include=['string']).columns

# Initialize OrdinalEncoder
encoder = OrdinalEncoder()

# Apply OrdinalEncoder to each string column
for col in string_columns:
    # Fit and transform the column using OrdinalEncoder
    X[col] = encoder.fit_transform(X[[col]])

X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12583 entries, 0 to 12582
# Data columns (total 59 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Listing ID                    12583 non-null  float64
#  1   Host Response Time            12583 non-null  float64
#  2   Host Response Rate            12583 non-null  float64
#  3   neighbourhood                 12583 non-null  float64
#  4   Neighborhood Group            12583 non-null  float64
#  5   Latitude                      12583 non-null  float64
#  6   Longitude                     12583 non-null  float64
#  7   Property Type                 12583 non-null  float64
#  8   Room Type                     12583 non-null  float64
#  9   Accomodates                   12583 non-null  float64
#  10  Bathrooms                     12583 non-null  float64
#  11  Bedrooms                      12583 non-null  float64
#  12  Beds                          12583 non-null  float64
#  13  Guests Included               12583 non-null  float64
#  14  Min Nights                    12583 non-null  float64
#  15  Reviews                       12583 non-null  float64
#  16  Overall Rating                12583 non-null  float64
#  17  Accuracy Rating               12583 non-null  float64
#  18  Cleanliness Rating            12583 non-null  float64
#  19  Checkin Rating                12583 non-null  float64
#  20  Communication Rating          12583 non-null  float64
#  21  Location Rating               12583 non-null  float64
#  22  Value Rating                  12583 non-null  float64
#  23  Is Superhost_ind              12583 non-null  float64
#  24  Is Exact Location_ind         12583 non-null  float64
#  25  Top10Neighbourhood            12583 non-null  float64
#  26  Property Type_groups          12583 non-null  float64
#  27  Host Response Rate_missing    12583 non-null  float64
#  28  Checkin Rating_missing        12583 non-null  float64
#  29  Value Rating_missing          12583 non-null  float64
#  30  Location Rating_missing       12583 non-null  float64
#  31  Accuracy Rating_missing       12583 non-null  float64
#  32  Communication Rating_missing  12583 non-null  float64
#  33  Cleanliness Rating_missing    12583 non-null  float64
#  34  Overall Rating_missing        12583 non-null  float64
#  35  Distance_to_Center            12583 non-null  float64
#  36  Location Rating_Avg           12583 non-null  float64
#  37  Attractive_Neighbourhood      12583 non-null  float64
#  38  Days Since Host Joined        12583 non-null  float64
#  39  Host Missing Indicator        12583 non-null  int64
#  40  Days Since First Joined       12583 non-null  float64
#  41  First Missing Indicator       12583 non-null  int64
#  42  Days Since Last Joined        12583 non-null  float64
#  43  Last Missing Indicator        12583 non-null  int64
#  44  Review Range (Days)           12583 non-null  float64
#  45  Reviews per Day Ratio         12583 non-null  float64
#  46  Bedrooms Binned               12583 non-null  float64
#  47  Guests Included Binned        12583 non-null  float64
#  48  Bathrooms Binned              12583 non-null  float64
#  49  Min Nights Binned             12583 non-null  float64
#  50  Accomodates Binned            12583 non-null  float64
#  51  Beds Binned                   12583 non-null  float64
#  52  Latitude Binned               12583 non-null  int64
#  53  Longitude Binned              12583 non-null  int64
#  54  time_diff_reviews             12583 non-null  float64
#  55  avg_polarity_all              12583 non-null  float64
#  56  avg_sentiment_all             12583 non-null  float64
#  57  avg_polarity_top_5            12583 non-null  float64
#  58  avg_sentiment_top_5           12583 non-null  float64
# dtypes: float64(54), int64(5)
# memory usage: 5.7 MB

# %%
# Fit models and determine if a feature is selected (1) or not (0)

# Lasso
lasso = Lasso(alpha=0.01).fit(X, y)
lasso_selected = (np.abs(lasso.coef_) > 0).astype(int)

# SVM
svm = LinearSVR(C=0.01, epsilon=0.1).fit(X, y)
svm_selected = (np.abs(svm.coef_) > 0).astype(int)

# Gradient Boosting
gb = GradientBoostingRegressor().fit(X, y)
gb_selected = (gb.feature_importances_ > 0).astype(int)

# Random Forest
rf = RandomForestRegressor().fit(X, y)
rf_selected = (rf.feature_importances_ > 0).astype(int)

# Linear Regression
linear_reg = LinearRegression().fit(X, y)
linear_reg_selected = (np.abs(linear_reg.coef_) > 0).astype(int)

# Ridge Regression
ridge = Ridge(alpha=1.0).fit(X, y)
ridge_selected = (np.abs(ridge.coef_) > 0).astype(int)

# Create a DataFrame to store results
selection_df = pd.DataFrame({
    'Feature': X.columns,
    'Lasso': lasso_selected,
    'SVM': svm_selected,
    'GradientBoost': gb_selected,
    'RandomForest': rf_selected,
    'LinearRegression': linear_reg_selected,
    'Ridge': ridge_selected
})

# Sum the number of selections for each feature
selection_df['Sum'] = selection_df[['Lasso', 'SVM', 'GradientBoost', 'RandomForest', 'LinearRegression', 'Ridge']].sum(axis=1)

# Output the results
print(selection_df)
# Out:
#                          Feature  Lasso  SVM  GradientBoost  RandomForest  \
# 0                     Listing ID      1    1              1             1
# 1             Host Response Time      0    1              1             1
# 2             Host Response Rate      1    1              1             1
# 3                  neighbourhood      1    1              1             1
# 4             Neighborhood Group      1    1              1             1
# 5                       Latitude      1    1              1             1
# 6                      Longitude      1    1              1             1
# 7                  Property Type      0    0              0             0
# 8                      Room Type      1    1              1             1
# 9                    Accomodates      1    1              1             1
# 10                     Bathrooms      1    1              1             1
# 11                      Bedrooms      1    1              1             1
# 12                          Beds      1    1              1             1
# 13               Guests Included      1    1              1             1
# 14                    Min Nights      1    1              1             1
# 15                       Reviews      1    1              1             1
# 16                Overall Rating      1    1              1             1
# 17               Accuracy Rating      1    1              1             1
# 18            Cleanliness Rating      1    1              1             1
# 19                Checkin Rating      1    1              1             1
# 20          Communication Rating      1    1              0             1
# 21               Location Rating      1    1              1             1
# 22                  Value Rating      1    1              1             1
# 23              Is Superhost_ind      1    1              0             1
# 24         Is Exact Location_ind      1    1              0             1
# 25            Top10Neighbourhood      1    1              1             1
# 26          Property Type_groups      0    0              0             0
# 27    Host Response Rate_missing      1    1              0             1
# 28        Checkin Rating_missing      1    1              0             1
# 29          Value Rating_missing      0    1              0             1
# 30       Location Rating_missing      0    1              1             1
# 31       Accuracy Rating_missing      1    1              1             1
# 32  Communication Rating_missing      1    1              0             1
# 33    Cleanliness Rating_missing      0    1              0             1
# 34        Overall Rating_missing      1    1              1             1
# 35            Distance_to_Center      1    1              1             1
# 36           Location Rating_Avg      1    1              1             1
# 37      Attractive_Neighbourhood      1    1              1             1
# 38        Days Since Host Joined      1    1              1             1
# 39        Host Missing Indicator      1    1              1             1
# 40       Days Since First Joined      1    1              1             1
# 41       First Missing Indicator      1    1              0             1
# 42        Days Since Last Joined      1    1              1             1
# 43        Last Missing Indicator      1    1              0             1
# 44           Review Range (Days)      1    1              1             1
# 45         Reviews per Day Ratio      1    1              1             1
# 46               Bedrooms Binned      1    1              1             1
# 47        Guests Included Binned      0    1              1             1
# 48              Bathrooms Binned      1    1              1             1
# 49             Min Nights Binned      1    1              1             1
# 50            Accomodates Binned      1    1              1             1
# 51                   Beds Binned      1    1              1             1
# 52               Latitude Binned      1    1              0             1
# 53              Longitude Binned      1    1              1             1
# 54             time_diff_reviews      1    1              1             1
# 55              avg_polarity_all      1    1              1             1
# 56             avg_sentiment_all      1    1              0             1
# 57            avg_polarity_top_5      1    1              1             1
# 58           avg_sentiment_top_5      0    1              0             1
#
#     LinearRegression  Ridge  Sum
# 0                  1      1    6
# 1                  1      1    5
# 2                  1      1    6
# 3                  1      1    6
# 4                  1      1    6
# 5                  1      1    6
# 6                  1      1    6
# 7                  1      0    1
# 8                  1      1    6
# 9                  1      1    6
# 10                 1      1    6
# 11                 1      1    6
# 12                 1      1    6
# 13                 1      1    6
# 14                 1      1    6
# 15                 1      1    6
# 16                 1      1    6
# 17                 1      1    6
# 18                 1      1    6
# 19                 1      1    6
# 20                 1      1    5
# 21                 1      1    6
# 22                 1      1    6
# 23                 1      1    5
# 24                 1      1    5
# 25                 1      1    6
# 26                 1      0    1
# 27                 1      1    5
# 28                 1      1    5
# 29                 1      1    4
# 30                 1      1    5
# 31                 1      1    6
# 32                 1      1    5
# 33                 1      1    4
# 34                 1      1    6
# 35                 1      1    6
# 36                 1      1    6
# 37                 1      1    6
# 38                 1      1    6
# 39                 1      1    6
# 40                 1      1    6
# 41                 1      1    5
# 42                 1      1    6
# 43                 1      1    5
# 44                 1      1    6
# 45                 1      1    6
# 46                 1      1    6
# 47                 1      1    5
# 48                 1      1    6
# 49                 1      1    6
# 50                 1      1    6
# 51                 1      1    6
# 52                 1      1    5
# 53                 1      1    6
# 54                 1      1    6
# 55                 1      1    6
# 56                 1      1    5
# 57                 1      1    6
# 58                 1      1    4

# %%
# Define the thresholds to test
thresholds = [1, 2, 3, 4, 5, 6]

# Create a dictionary to store the count of features for each threshold
count_dict = {}

for threshold in thresholds:
    selected_features = selection_df[selection_df['Sum'] >= threshold]['Feature']
    count_dict[threshold] = len(selected_features)

# Convert the dictionary to a DataFrame for better visualization
count_df = pd.DataFrame(list(count_dict.items()), columns=['Threshold', 'Feature Count'])

# Print the results
print(count_df)
# Out:
#    Threshold  Feature Count
# 0          1             59
# 1          2             57
# 2          3             57
# 3          4             57
# 4          5             54
# 5          6             41

# %%
 #Selecting variables with a sum of selections >= 4
final_var = selection_df[selection_df['Sum'] >=4 ]
final_var
# Out:
#                          Feature  Lasso  SVM  GradientBoost  RandomForest  \
# 0                     Listing ID      1    1              1             1
# 1             Host Response Time      0    1              1             1
# 2             Host Response Rate      1    1              1             1
# 3                  neighbourhood      1    1              1             1
# 4             Neighborhood Group      1    1              1             1
# 5                       Latitude      1    1              1             1
# 6                      Longitude      1    1              1             1
# 8                      Room Type      1    1              1             1
# 9                    Accomodates      1    1              1             1
# 10                     Bathrooms      1    1              1             1
# 11                      Bedrooms      1    1              1             1
# 12                          Beds      1    1              1             1
# 13               Guests Included      1    1              1             1
# 14                    Min Nights      1    1              1             1
# 15                       Reviews      1    1              1             1
# 16                Overall Rating      1    1              1             1
# 17               Accuracy Rating      1    1              1             1
# 18            Cleanliness Rating      1    1              1             1
# 19                Checkin Rating      1    1              1             1
# 20          Communication Rating      1    1              0             1
# 21               Location Rating      1    1              1             1
# 22                  Value Rating      1    1              1             1
# 23              Is Superhost_ind      1    1              0             1
# 24         Is Exact Location_ind      1    1              0             1
# 25            Top10Neighbourhood      1    1              1             1
# 27    Host Response Rate_missing      1    1              0             1
# 28        Checkin Rating_missing      1    1              0             1
# 29          Value Rating_missing      0    1              0             1
# 30       Location Rating_missing      0    1              1             1
# 31       Accuracy Rating_missing      1    1              1             1
# 32  Communication Rating_missing      1    1              0             1
# 33    Cleanliness Rating_missing      0    1              0             1
# 34        Overall Rating_missing      1    1              1             1
# 35            Distance_to_Center      1    1              1             1
# 36           Location Rating_Avg      1    1              1             1
# 37      Attractive_Neighbourhood      1    1              1             1
# 38        Days Since Host Joined      1    1              1             1
# 39        Host Missing Indicator      1    1              1             1
# 40       Days Since First Joined      1    1              1             1
# 41       First Missing Indicator      1    1              0             1
# 42        Days Since Last Joined      1    1              1             1
# 43        Last Missing Indicator      1    1              0             1
# 44           Review Range (Days)      1    1              1             1
# 45         Reviews per Day Ratio      1    1              1             1
# 46               Bedrooms Binned      1    1              1             1
# 47        Guests Included Binned      0    1              1             1
# 48              Bathrooms Binned      1    1              1             1
# 49             Min Nights Binned      1    1              1             1
# 50            Accomodates Binned      1    1              1             1
# 51                   Beds Binned      1    1              1             1
# 52               Latitude Binned      1    1              0             1
# 53              Longitude Binned      1    1              1             1
# 54             time_diff_reviews      1    1              1             1
# 55              avg_polarity_all      1    1              1             1
# 56             avg_sentiment_all      1    1              0             1
# 57            avg_polarity_top_5      1    1              1             1
# 58           avg_sentiment_top_5      0    1              0             1
#
#     LinearRegression  Ridge  Sum
# 0                  1      1    6
# 1                  1      1    5
# 2                  1      1    6
# 3                  1      1    6
# 4                  1      1    6
# 5                  1      1    6
# 6                  1      1    6
# 8                  1      1    6
# 9                  1      1    6
# 10                 1      1    6
# 11                 1      1    6
# 12                 1      1    6
# 13                 1      1    6
# 14                 1      1    6
# 15                 1      1    6
# 16                 1      1    6
# 17                 1      1    6
# 18                 1      1    6
# 19                 1      1    6
# 20                 1      1    5
# 21                 1      1    6
# 22                 1      1    6
# 23                 1      1    5
# 24                 1      1    5
# 25                 1      1    6
# 27                 1      1    5
# 28                 1      1    5
# 29                 1      1    4
# 30                 1      1    5
# 31                 1      1    6
# 32                 1      1    5
# 33                 1      1    4
# 34                 1      1    6
# 35                 1      1    6
# 36                 1      1    6
# 37                 1      1    6
# 38                 1      1    6
# 39                 1      1    6
# 40                 1      1    6
# 41                 1      1    5
# 42                 1      1    6
# 43                 1      1    5
# 44                 1      1    6
# 45                 1      1    6
# 46                 1      1    6
# 47                 1      1    5
# 48                 1      1    6
# 49                 1      1    6
# 50                 1      1    6
# 51                 1      1    6
# 52                 1      1    5
# 53                 1      1    6
# 54                 1      1    6
# 55                 1      1    6
# 56                 1      1    5
# 57                 1      1    6
# 58                 1      1    4

# %%
final_var = selection_df[selection_df['Sum'] >=4 ]['Feature'].tolist()
final_var
# Out:
# ['Listing ID',
#  'Host Response Time',
#  'Host Response Rate',
#  'neighbourhood',
#  'Neighborhood Group',
#  'Latitude',
#  'Longitude',
#  'Room Type',
#  'Accomodates',
#  'Bathrooms',
#  'Bedrooms',
#  'Beds',
#  'Guests Included',
#  'Min Nights',
#  'Reviews',
#  'Overall Rating',
#  'Accuracy Rating',
#  'Cleanliness Rating',
#  'Checkin Rating',
#  'Communication Rating',
#  'Location Rating',
#  'Value Rating',
#  'Is Superhost_ind',
#  'Is Exact Location_ind',
#  'Top10Neighbourhood',
#  'Host Response Rate_missing',
#  'Checkin Rating_missing',
#  'Value Rating_missing',
#  'Location Rating_missing',
#  'Accuracy Rating_missing',
#  'Communication Rating_missing',
#  'Cleanliness Rating_missing',
#  'Overall Rating_missing',
#  'Distance_to_Center',
#  'Location Rating_Avg',
#  'Attractive_Neighbourhood',
#  'Days Since Host Joined',
#  'Host Missing Indicator',
#  'Days Since First Joined',
#  'First Missing Indicator',
#  'Days Since Last Joined',
#  'Last Missing Indicator',
#  'Review Range (Days)',
#  'Reviews per Day Ratio',
#  'Bedrooms Binned',
#  'Guests Included Binned',
#  'Bathrooms Binned',
#  'Min Nights Binned',
#  'Accomodates Binned',
#  'Beds Binned',
#  'Latitude Binned',
#  'Longitude Binned',
#  'time_diff_reviews',
#  'avg_polarity_all',
#  'avg_sentiment_all',
#  'avg_polarity_top_5',
#  'avg_sentiment_top_5']

# %%
df_model = feature_sele_df[final_var].copy()
df_model['Price'] = feature_sele_df['Price'].copy()

# %%
df_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12583 entries, 0 to 12582
# Data columns (total 58 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Listing ID                    12583 non-null  float64
#  1   Host Response Time            12583 non-null  string
#  2   Host Response Rate            12583 non-null  float64
#  3   neighbourhood                 12583 non-null  string
#  4   Neighborhood Group            12583 non-null  string
#  5   Latitude                      12583 non-null  float64
#  6   Longitude                     12583 non-null  float64
#  7   Room Type                     12583 non-null  string
#  8   Accomodates                   12583 non-null  float64
#  9   Bathrooms                     12583 non-null  float64
#  10  Bedrooms                      12583 non-null  float64
#  11  Beds                          12583 non-null  float64
#  12  Guests Included               12583 non-null  float64
#  13  Min Nights                    12583 non-null  float64
#  14  Reviews                       12583 non-null  float64
#  15  Overall Rating                12583 non-null  float64
#  16  Accuracy Rating               12583 non-null  float64
#  17  Cleanliness Rating            12583 non-null  float64
#  18  Checkin Rating                12583 non-null  float64
#  19  Communication Rating          12583 non-null  float64
#  20  Location Rating               12583 non-null  float64
#  21  Value Rating                  12583 non-null  float64
#  22  Is Superhost_ind              12583 non-null  float64
#  23  Is Exact Location_ind         12583 non-null  float64
#  24  Top10Neighbourhood            12583 non-null  string
#  25  Host Response Rate_missing    12583 non-null  float64
#  26  Checkin Rating_missing        12583 non-null  float64
#  27  Value Rating_missing          12583 non-null  float64
#  28  Location Rating_missing       12583 non-null  float64
#  29  Accuracy Rating_missing       12583 non-null  float64
#  30  Communication Rating_missing  12583 non-null  float64
#  31  Cleanliness Rating_missing    12583 non-null  float64
#  32  Overall Rating_missing        12583 non-null  float64
#  33  Distance_to_Center            12583 non-null  float64
#  34  Location Rating_Avg           12583 non-null  float64
#  35  Attractive_Neighbourhood      12583 non-null  float64
#  36  Days Since Host Joined        12583 non-null  float64
#  37  Host Missing Indicator        12583 non-null  int64
#  38  Days Since First Joined       12583 non-null  float64
#  39  First Missing Indicator       12583 non-null  int64
#  40  Days Since Last Joined        12583 non-null  float64
#  41  Last Missing Indicator        12583 non-null  int64
#  42  Review Range (Days)           12583 non-null  float64
#  43  Reviews per Day Ratio         12583 non-null  float64
#  44  Bedrooms Binned               12583 non-null  string
#  45  Guests Included Binned        12583 non-null  string
#  46  Bathrooms Binned              12583 non-null  string
#  47  Min Nights Binned             12583 non-null  string
#  48  Accomodates Binned            12583 non-null  string
#  49  Beds Binned                   12583 non-null  string
#  50  Latitude Binned               12583 non-null  int64
#  51  Longitude Binned              12583 non-null  int64
#  52  time_diff_reviews             12583 non-null  float64
#  53  avg_polarity_all              12583 non-null  float64
#  54  avg_sentiment_all             12583 non-null  float64
#  55  avg_polarity_top_5            12583 non-null  float64
#  56  avg_sentiment_top_5           12583 non-null  float64
#  57  Price                         12583 non-null  float64
# dtypes: float64(42), int64(5), string(11)
# memory usage: 5.6 MB

# %%
df_model
# Out:
#        Listing ID  Host Response Time  Host Response Rate       neighbourhood  \
# 0      13761071.0  within a few hours                 1.0               Mitte
# 1      13763834.0             Missing                -2.0           Neuk̦lln
# 2      13764102.0             Missing                -2.0               Mitte
# 3      13764166.0             Missing                -2.0      Charlottenburg
# 4      13765505.0             Missing                -2.0     Prenzlauer Berg
# ...           ...                 ...                 ...                 ...
# 12578   9991497.0             Missing                -2.0  Niedersch̦neweide
# 12579   9993168.0             Missing                -2.0         Rummelsburg
# 12580   9994644.0      within an hour                 1.0           Kreuzberg
# 12581    999465.0             Missing                -2.0      Friedrichshain
# 12582   9996186.0  within a few hours                 1.0             Wedding
#
#              Neighborhood Group  Latitude  Longitude        Room Type  \
# 0                         Mitte  52.50920   13.41762  Entire home/apt
# 1                     Neuk̦lln  52.46713   13.42733  Entire home/apt
# 2                         Mitte  52.53294   13.40649     Private room
# 3          Charlottenburg-Wilm.  52.52670   13.30916     Private room
# 4                        Pankow  52.53924   13.43521     Private room
# ...                         ...       ...        ...              ...
# 12578       Treptow - K̦penick  52.45494   13.51423  Entire home/apt
# 12579               Lichtenberg  52.50099   13.49185     Private room
# 12580  Friedrichshain-Kreuzberg  52.50283   13.37799  Entire home/apt
# 12581  Friedrichshain-Kreuzberg  52.51001   13.45366  Entire home/apt
# 12582                     Mitte  52.53806   13.38776  Entire home/apt
#
#        Accomodates  Bathrooms  ...  Accomodates Binned  Beds Binned  \
# 0              6.0        1.0  ...         (5.0, 16.0]  (3.5, 12.0]
# 1              2.0        1.0  ...          (1.0, 2.0]   (1.0, 2.0]
# 2              2.0        1.0  ...          (1.0, 2.0]   (0.0, 1.0]
# 3              2.0        1.0  ...          (1.0, 2.0]   (0.0, 1.0]
# 4              1.0        1.0  ...        (0.499, 1.0]   (0.0, 1.0]
# ...            ...        ...  ...                 ...          ...
# 12578          6.0        1.0  ...         (5.0, 16.0]   (1.0, 2.0]
# 12579          2.0        1.0  ...          (1.0, 2.0]   (0.0, 1.0]
# 12580          4.0        1.0  ...          (3.0, 4.0]   (2.0, 3.0]
# 12581          9.0        1.5  ...         (5.0, 16.0]  (3.5, 12.0]
# 12582          2.0        2.0  ...          (1.0, 2.0]   (0.0, 1.0]
#
#        Latitude Binned  Longitude Binned  time_diff_reviews  avg_polarity_all  \
# 0                    2                 2                8.0          0.346960
# 1                    1                 2               28.0          0.368619
# 2                    3                 2               -2.0          0.000000
# 3                    2                 1               -2.0          0.000000
# 4                    3                 2               13.0          0.381355
# ...                ...               ...                ...               ...
# 12578                1                 3                0.0          0.000000
# 12579                2                 2                6.0          0.295728
# 12580                2                 2                3.0          0.392852
# 12581                2                 2              109.0          0.250186
# 12582                3                 2              499.0          0.412963
#
#        avg_sentiment_all  avg_polarity_top_5  avg_sentiment_top_5  Price
# 0                    1.0            0.310000                  1.0  109.0
# 1                    1.0            0.194133                  1.0   50.0
# 2                    0.0            0.000000                  0.0   69.0
# 3                    0.0            0.000000                  0.0   30.0
# 4                    1.0            0.385260                  1.0   25.0
# ...                  ...                 ...                  ...    ...
# 12578                0.0            0.000000                  0.0   50.0
# 12579                1.0            0.334960                  1.0   20.0
# 12580                1.0            0.536611                  1.0   60.0
# 12581                1.0            0.250186                  1.0  150.0
# 12582                1.0            0.412963                  1.0   80.0
#
# [12583 rows x 58 columns]

# %%
df_model.to_pickle('step_5_df.pkl')
